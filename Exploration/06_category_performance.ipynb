# %%
import pandas as pd

# %%
df_books = pd.read_parquet('../Input/bookes_data_category_clustered.parquet')
print("df_books shape:", df_books.shape)

df_ratings = pd.read_csv('../Input/Books_rating.csv')
df_ratings['time'] = pd.to_datetime(df_ratings['time'], unit='s')
print("df_ratings shape", df_ratings.shape)

df = pd.merge(df_books, df_ratings, on='Title')

del df_books, df_ratings
# Out:
# df_books shape: (40635, 14)
# df_ratings shape (3000000, 9)

# %%
print(df.shape)
df.head()
# Out:
# (1401385, 22)
#                                                Title  \
# 0  The Church of Christ: A Biblical Ecclesiology ...
# 1  The Church of Christ: A Biblical Ecclesiology ...
# 2  The Church of Christ: A Biblical Ecclesiology ...
# 3  The Church of Christ: A Biblical Ecclesiology ...
# 4  Voices from the Farm: Adventures in Community ...
#
#                                          description               authors  \
# 0  In The Church of Christ: A Biblical Ecclesiolo...  ['Everett Ferguson']
# 1  In The Church of Christ: A Biblical Ecclesiolo...  ['Everett Ferguson']
# 2  In The Church of Christ: A Biblical Ecclesiolo...  ['Everett Ferguson']
# 3  In The Church of Christ: A Biblical Ecclesiolo...  ['Everett Ferguson']
# 4  Twenty-five years ago, at the height of the co...       ['Rupert Fike']
#
#                                                image  \
# 0  http://books.google.com/books/content?id=kVqRa...
# 1  http://books.google.com/books/content?id=kVqRa...
# ...
